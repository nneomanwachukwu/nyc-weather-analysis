# %% [markdown]
# # 31-Day NYC Weather Analysis
#
# **Analysing 31 days of New York City weather data using python, pandas, and data visualization techniques**

# %%
# importing the relavant modules
import pandas as pd
import numpy as np 
import mysql.connector as dbconnect
import mysql.connector as mysqlconnector
from sqlalchemy import create_engine

import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# (a) Use the numpy and pandas modules to read the csv file and clean up the data as best as you could do

# %%
# Function to read a CSV File,
def get_df_from_csv(file):
    try:
        nyc_weather = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        print(f"The {file} CSV File was read successfully")
        return nyc_weather

# %%
# Calling the function to import data from csv file
file = r"nyc_weather.csv"
nyc_weather = get_df_from_csv(file)
# Out:
# The nyc_weather.csv CSV File was read successfully

# %%
# Confirming if the dataframe is empty
nyc_weather.empty
# Out:
# False

# %%
# Check first 5 records of the dataframe
nyc_weather.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/2016           38        23        52                 30.03
# 1  01/02/2016           36        18        46                 30.02
# 2  01/03/2016           40        21        47                 29.86
# 3  01/04/2016           25         9        44                 30.05
# 4  01/05/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
# Check last 5 records of the dataframe
nyc_weather.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
# Confirm data records
nyc_weather.shape
# Out:
# (31, 11)

# %%
# check if there are empty records in the dataframe
nyc_weather.isna().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
# List all the column headers of the dataframe
nyc_weather.columns.tolist()
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
# Use the info() function to check the data structure of the dataframe
nyc_weather.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     str
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     str
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      str
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), str(3)
# memory usage: 3.2 KB

# %%
# check for duplicate data
nyc_weather.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check statistical summary of the dataframe
nyc_weather.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
nyc_weather
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01/01/2016           38        23        52                 30.03
# 1   01/02/2016           36        18        46                 30.02
# 2   01/03/2016           40        21        47                 29.86
# 3   01/04/2016           25         9        44                 30.05
# 4   01/05/2016           20        -3        41                 30.57
# 5   01/06/2016           33         4        35                 30.50
# 6   01/07/2016           39        11        33                 30.28
# 7   01/08/2016           39        29        64                 30.20
# 8   01/09/2016           44        38        77                 30.16
# 9   01/10/2016           50        46        71                 29.59
# 10  01/11/2016           33         8        37                 29.92
# 11  01/12/2016           35        15        53                 29.85
# ...

# %%
# from the data, replacesall letter T to (0.0), NaN in the column PrecipitationIn WITH (0.0), and all Nan in Event with 'Not Available
nyc_weather['PrecipitationIn'] = nyc_weather['PrecipitationIn'].replace(r"T",0.0) 
nyc_weather['WindSpeedMPH'] = nyc_weather['WindSpeedMPH'].fillna(0.0)
nyc_weather['Events'] = nyc_weather['Events'].fillna('Not Available')
nyc_weather[15:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# ...

# %%
nyc_weather.isna().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
# [int8: -128 to 127]; [unint8: 0 to 255]; [int16: -32,768 to 32,767]; [uint16: 0 to 65,537]
# [int32: -2,147,483,648 to-2,147,483,647]; [unint32: 0 to 4,294,967,296]; 
# [int64: -9,223,372,036,854,776 to -9,223,372,036,854,775]; [uint64: 0 to 18,446,744,073,709,551,616]
# [float8, float16, float32, float32, float64] follows similar pattern but no unsigned float [unfloat]

# %%
nyc_weather.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     str
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                31 non-null     str
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(1), str(2)
# memory usage: 3.4+ KB

# %%
#Converting all the columns into the appropriate datatype

# Convert EST to datetime
nyc_weather['EST'] = pd.to_datetime(nyc_weather['EST'])
nyc_weather.set_index('EST', inplace=True)

# Integer columns
integer_columns = [
    'Temperature',
    'DewPoint',
    'Humidity',
    'VisibilityMiles',
    'CloudCover',
    'WindDirDegrees']

for column in integer_columns:
    nyc_weather[column] = nyc_weather[column].astype('int16')

# Float columns
float_columns = ['Sea Level PressureIn','WindSpeedMPH']

for column in float_columns:
    nyc_weather[column] = nyc_weather[column].astype('float16')

# String columns
string_columns = ['PrecipitationIn','Events']

for column in string_columns:
    nyc_weather[column] = nyc_weather[column].astype('string')

nyc_weather.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 31 entries, 2016-01-01 to 2016-01-31
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           31 non-null     int16
#  1   DewPoint              31 non-null     int16
#  2   Humidity              31 non-null     int16
#  3   Sea Level PressureIn  31 non-null     float16
#  4   VisibilityMiles       31 non-null     int16
#  5   WindSpeedMPH          31 non-null     float16
#  6   PrecipitationIn       31 non-null     string
#  7   CloudCover            31 non-null     int16
#  8   Events                31 non-null     string
#  9   WindDirDegrees        31 non-null     int16
# dtypes: float16(2), int16(6), string(2)
# memory usage: 1.6 KB

# %%
nyc_weather.columns.tolist()
# Out:
# ['Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
# Rearranging the column in a professional order while preserving the data

nyc_weather = nyc_weather[[
        'Temperature',
        'DewPoint',
        'Humidity',
        'Sea Level PressureIn',
        'VisibilityMiles',
        'WindSpeedMPH',
        'WindDirDegrees',
        'CloudCover',
        'PrecipitationIn',
        'Events']]

# %%
nyc_weather.head()
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52             30.031250
# 2016-01-02           36        18        46             30.015625
# 2016-01-03           40        21        47             29.859375
# 2016-01-04           25         9        44             30.046875
# 2016-01-05           20        -3        41             30.562500
#
#             VisibilityMiles  WindSpeedMPH  WindDirDegrees  CloudCover  \
# EST
# 2016-01-01               10           8.0             281           5
# 2016-01-02               10           7.0             275           3
# 2016-01-03               10           8.0             277           1
# 2016-01-04               10           9.0             345           3
# 2016-01-05               10           5.0             333           0
#
#            PrecipitationIn         Events
# EST
# 2016-01-01               0  Not Available
# 2016-01-02               0  Not Available
# ...

# %%
# Analysing Temperature conditions 
print('TEMPERATURE ANALYSIS')
print('-' * 20)
print(nyc_weather['Temperature'].describe())
nyc_weather_Temp_max = nyc_weather.loc[nyc_weather['Temperature'].idxmax()]
nyc_weather_Temp_min = nyc_weather['Temperature'].idxmin()
print('\n')
print(f'Max Temperature: {nyc_weather_Temp_max}')
print('\n')
print(f'Max Temperature: {nyc_weather_Temp_max}')
# Out:
# TEMPERATURE ANALYSIS
# --------------------
# count    31.000000
# mean     34.677419
# std       7.639315
# min      20.000000
# 25%      29.000000
# 50%      35.000000
# 75%      39.500000
# max      50.000000
# Name: Temperature, dtype: float64
#
#
# Max Temperature: Temperature                   50
# DewPoint                      46
# Humidity                      71
# Sea Level PressureIn    29.59375
# VisibilityMiles                4
# WindSpeedMPH                 0.0
# WindDirDegrees               109
# CloudCover                     7
# PrecipitationIn              1.8
# Events                      Rain
# Name: 2016-01-10 00:00:00, dtype: object
#
#
# Max Temperature: Temperature                   50
# DewPoint                      46
# Humidity                      71
# Sea Level PressureIn    29.59375
# VisibilityMiles                4
# WindSpeedMPH                 0.0
# WindDirDegrees               109
# CloudCover                     7
# PrecipitationIn              1.8
# ...

# %%
# Import Plotly Express for creating interactive visualizations
import plotly.express as px

# Create an interactive line chart to show daily temperature variations
fig = px.line(
    nyc_weather,
    x=nyc_weather.index,           # Use the DateTime index (EST) as the x-axis
    y='Temperature',               # Plot daily temperature values
    title='Daily Temperature Trend NYC',
    markers=True)                   # Display markers for each observation


# Customize the appearance of the line and markers
fig.update_traces(
    line=dict(color='red', width=3),
    marker=dict(
        color='red',
        size=8,
        symbol='circle'))

# Improve the chart layout and readability
fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Temperature (°F)',
    template='plotly_white',
    hovermode='x unified')

# Save and Display the interactive chart
plt.savefig('Daily Temperature Trend NYC.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
# checking for how much moisture that was in the air

print('DEW POINT ANALYSIS')
print('-' * 18)
print(nyc_weather['DewPoint'].describe())
Average_Dew_Point = nyc_weather['DewPoint'].mean()
Dew_Point_max = nyc_weather['DewPoint'].idxmax()
print('\n')
print(f'Average Dew Point: {Average_Dew_Point:,.2f}')
print('\n')
#print(f'Max Dew Point: {Dew_Point_max}')
date = nyc_weather['DewPoint'].idxmax()
Dew_Point_max = nyc_weather['DewPoint'].max()
print(f' Date: {date}')
print(f'Maximum Dew Point: {Dew_Point_max}')
# Out:
# DEW POINT ANALYSIS
# ------------------
# count   31.00
# mean    17.84
# std     11.38
# min     -3.00
# 25%     10.00
# 50%     18.00
# 75%     23.00
# max     46.00
# Name: DewPoint, dtype: float64
#
#
# Average Dew Point: 17.84
#
#
#  Date: 2016-01-10 00:00:00
# Maximum Dew Point: 46

# %%
# Import Plotly Express
import plotly.express as px

# Create an interactive line chart to visualize daily dew point values
fig = px.line(
    nyc_weather,
    x=nyc_weather.index,
    y='DewPoint',
    title='Daily Dew Point Trend',
    markers=True)

# Customize the chart appearance
fig.update_traces(
    line=dict(
        color='royalblue',
        width=3,
        dash='dash'
    ),
    marker=dict(
        color='royalblue',
        size=8,
        symbol='diamond'))

# Improve chart layout
fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Dew Point (°F)',
    template='plotly_white',
    hovermode='x unified')

# Save and Display the interactive chart
plt.savefig('Daily Dew Point Trend.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
print('HUMIDIty ANALYSIS')
print('-' * 18)
print(nyc_weather['Humidity'].describe())
#Average_Dew_Point = nyc_weather['DewPoint'].mean()
Humidity_Point_max = nyc_weather['Humidity'].max()
Humidity_Point_min = nyc_weather['Humidity'].min()
print('\n')
#print(f'Average Dew Point: {Average_Dew_Point:,.2f}')
#print('\n')
#print(f'Max Dew Point: {Dew_Point_max}')
#date = nyc_weather['Humidity'].idxmax()
#Dew_Point_max = nyc_weather['Humidity'].max()
print(f'Date: {date}')
print(f'Highest Humidity: {Humidity_Point_max}')
print(f'Lowest Humidity: {Humidity_Point_min}')
# Out:
# HUMIDIty ANALYSIS
# ------------------
# count   31.00
# mean    51.68
# std     11.63
# min     33.00
# 25%     44.50
# 50%     50.00
# 75%     55.00
# max     78.00
# Name: Humidity, dtype: float64
#
#
# Date: 2016-01-10 00:00:00
# Highest Humidity: 78
# Lowest Humidity: 33

# %%
# Import Plotly Express
import plotly.express as px

# Create an interactive line chart to display daily humidity levels
fig = px.line(
    nyc_weather,
    x=nyc_weather.index,
    y='Humidity',
    title='Daily Humidity Trend',
    markers=True)

# Customize the line and marker styles
fig.update_traces(
    line=dict(
        color='green',
        width=3),
    marker=dict(
        color='green',
        size=8,
        symbol='square'))

# Improve the chart layout
fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Humidity (%)',
    template='plotly_white',
    hovermode='x unified')

# Save and Display the interactive chart
plt.savefig('Daily Humidity Trend.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
print('SEA LEVEL PRESSURE SUMMARY')
print('-' * 27)
print(nyc_weather['Sea Level PressureIn'].describe())
max_Pressure = nyc_weather['Sea Level PressureIn'].max()
min_Pressure = nyc_weather['Sea Level PressureIn'].min()
print('\n')
print(f'Highest Pressure: {max_Pressure}')
print(f'Lowest Pressure: {min_Pressure}')
# Out:
# SEA LEVEL PRESSURE SUMMARY
# ---------------------------
# count   31.00
# mean    30.00
# std      0.24
# min     29.52
# 25%     29.85
# 50%     30.02
# 75%     30.14
# max     30.56
# Name: Sea Level PressureIn, dtype: float64
#
#
# Highest Pressure: 30.5625
# Lowest Pressure: 29.515625

# %%
# Import Plotly Express for creating interactive visualizations
import plotly.express as px

# Create an interactive line chart to visualize daily sea level pressure
fig = px.line(
    nyc_weather,
    x=nyc_weather.index,              # Use the DateTime index (EST) as the x-axis
    y='Sea Level PressureIn',         # Plot sea level pressure values
    title='Daily Sea Level Pressure Trend',
    markers=True)                      # Display markers for each day's observation

# Customize the appearance of the line and markers
fig.update_traces(
    line=dict(
        color='darkblue',
        width=3,
        dash='longdash'
    ),
    marker=dict(
        color='gold',
        size=9,
        symbol='star'))

# Improve the overall layout of the chart
fig.update_layout(
    template='plotly_white',
    xaxis_title='Date',
    yaxis_title='Sea Level Pressure (in)',
    hovermode='x unified')

# Save and Display the interactive chart
plt.savefig('Daily Sea Level Pressure Trend.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
print('WIND SPEED SUMMARY')
print('-' * 18)
print(nyc_weather['WindSpeedMPH'].describe())
Ave_WindSpeed = nyc_weather['WindSpeedMPH'].mean()
Max_WindSpeed = nyc_weather['WindSpeedMPH'].max()
print('\n')
print(f'Average Wind Speed: {Ave_WindSpeed:,.2f}')
print(f'Highest Wind Speed: {Max_WindSpeed}')
# Out:
# WIND SPEED SUMMARY
# ------------------
# count   31.00
# mean     6.23
# std      3.42
# min      0.00
# 25%      5.00
# 50%      6.00
# 75%      8.00
# max     16.00
# Name: WindSpeedMPH, dtype: float64
#
#
# Average Wind Speed: 6.23
# Highest Wind Speed: 16.0

# %%
# Import Plotly Express

# Create an interactive line chart to visualize daily wind speed
fig = px.line(
    nyc_weather,
    x=nyc_weather.index,
    y='WindSpeedMPH',
    title='Daily Wind Speed Trend',
    markers=True)

# Customize the appearance of the chart
fig.update_traces(
    line=dict(
        color='purple',
        width=3,
        dash='dot'),
    marker=dict(
        color='purple',
        size=8,
        symbol='triangle-up'))

# Improve the chart layout
fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Wind Speed (MPH)',
    template='plotly_white',
    hovermode='x unified')

# Save and Display the interactive chart
plt.savefig('Daily Wind Speed Trend.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
Correlation = nyc_weather.corr(numeric_only=True)
print(Correlation)
# Out:
#                       Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature                  1.00      0.88      0.45                 -0.37
# DewPoint                     0.88      1.00      0.78                 -0.52
# Humidity                     0.45      0.78      1.00                 -0.51
# Sea Level PressureIn        -0.37     -0.52     -0.51                  1.00
# VisibilityMiles             -0.06     -0.37     -0.66                  0.43
# WindSpeedMPH                -0.33     -0.09      0.27                 -0.25
# WindDirDegrees              -0.22     -0.41     -0.50                  0.03
# CloudCover                   0.31      0.59      0.74                 -0.37
#
#                       VisibilityMiles  WindSpeedMPH  WindDirDegrees  \
# Temperature                     -0.06         -0.33           -0.22
# DewPoint                        -0.37         -0.09           -0.41
# Humidity                        -0.66          0.27           -0.50
# ...

# %%
# Import Plotly Express
import plotly.express as px

# Calculate the correlation matrix using only numeric variables
correlation = nyc_weather.corr(numeric_only=True)

# Create an interactive heatmap of the correlation matrix
fig = px.imshow(
    correlation,
    text_auto=True,                   # Display correlation values inside each cell
    color_continuous_scale='RdBu_r',  # Blue = positive, Red = negative
    title='Correlation Matrix of Weather Variables')

# Improve the chart layout
fig.update_layout(
    template='plotly_white')

# Save and Display the interactive chart
plt.savefig('Correlation Matrix of Weather Variables.png', bbox_inches='tight', pad_inches=0.2, dpi=300)
fig.show()

# %%
nyc_weather.describe()
# Out:
#        Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# count        31.00     31.00     31.00                 31.00            31.00
# mean         34.68     17.84     51.68                 30.00             9.19
# std           7.64     11.38     11.63                  0.24             1.94
# min          20.00     -3.00     33.00                 29.52             1.00
# 25%          29.00     10.00     44.50                 29.85             9.00
# 50%          35.00     18.00     50.00                 30.02            10.00
# 75%          39.50     23.00     55.00                 30.14            10.00
# max          50.00     46.00     78.00                 30.56            10.00
#
#        WindSpeedMPH  WindDirDegrees  CloudCover
# count         31.00           31.00       31.00
# mean           6.23          247.13        3.13
# std            3.42           92.31        2.63
# min            0.00           34.00        0.00
# ...
